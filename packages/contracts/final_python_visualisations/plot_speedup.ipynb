# %% [markdown]
# # Get Data
# Run `yarn run speed-up-measurement`
#
# Grab all of that rows that look like
# `"TALLY_PROOFS_MACHINES_1_BATCH_0_NUM_INPUTS_201":512.230954417,`
# from the output JSON and put them in `data_str` below

# %%
import json

save_time = 86.032990708 
data_str = """{
    "TALLY_PROOFS_MACHINES_1_BATCH_0_NUM_INPUTS_401": 987.759940375,
    "TALLY_PROOFS_MACHINES_2_BATCH_0_NUM_INPUTS_201": 486.205322291,
    "TALLY_PROOFS_MACHINES_2_BATCH_1_NUM_INPUTS_200": 483.781318417,
    "TALLY_PROOFS_MACHINES_4_BATCH_0_NUM_INPUTS_101": 241.455927709,
    "TALLY_PROOFS_MACHINES_4_BATCH_1_NUM_INPUTS_100": 239.16734575,
    "TALLY_PROOFS_MACHINES_4_BATCH_2_NUM_INPUTS_100": 238.24091716700002,
    "TALLY_PROOFS_MACHINES_4_BATCH_3_NUM_INPUTS_100": 238.85565325,
    "TALLY_PROOFS_MACHINES_8_BATCH_0_NUM_INPUTS_51": 123.46883529200001,
    "TALLY_PROOFS_MACHINES_8_BATCH_1_NUM_INPUTS_50": 113.355318667,
    "TALLY_PROOFS_MACHINES_8_BATCH_2_NUM_INPUTS_50": 113.533700167,
    "TALLY_PROOFS_MACHINES_8_BATCH_3_NUM_INPUTS_50": 114.016527208,
    "TALLY_PROOFS_MACHINES_8_BATCH_4_NUM_INPUTS_50": 113.768838458,
    "TALLY_PROOFS_MACHINES_8_BATCH_5_NUM_INPUTS_50": 114.7355625,
    "TALLY_PROOFS_MACHINES_8_BATCH_6_NUM_INPUTS_50": 121.70149458300001,
    "TALLY_PROOFS_MACHINES_8_BATCH_7_NUM_INPUTS_50": 113.11504062499999,
    "TALLY_PROOFS_MACHINES_16_BATCH_0_NUM_INPUTS_26": 59.515740124999994,
    "TALLY_PROOFS_MACHINES_16_BATCH_1_NUM_INPUTS_25": 57.18515475,
    "TALLY_PROOFS_MACHINES_16_BATCH_2_NUM_INPUTS_25": 57.004314459,
    "TALLY_PROOFS_MACHINES_16_BATCH_3_NUM_INPUTS_25": 57.138113708,
    "TALLY_PROOFS_MACHINES_16_BATCH_4_NUM_INPUTS_25": 57.338818083,
    "TALLY_PROOFS_MACHINES_16_BATCH_5_NUM_INPUTS_25": 61.71881625,
    "TALLY_PROOFS_MACHINES_16_BATCH_6_NUM_INPUTS_25": 57.328732167000005,
    "TALLY_PROOFS_MACHINES_16_BATCH_7_NUM_INPUTS_25": 57.077980542,
    "TALLY_PROOFS_MACHINES_16_BATCH_8_NUM_INPUTS_25": 61.4819125,
    "TALLY_PROOFS_MACHINES_16_BATCH_9_NUM_INPUTS_25": 57.076281041,
    "TALLY_PROOFS_MACHINES_16_BATCH_10_NUM_INPUTS_25": 57.287734208,
    "TALLY_PROOFS_MACHINES_16_BATCH_11_NUM_INPUTS_25": 61.808242959000005,
    "TALLY_PROOFS_MACHINES_16_BATCH_12_NUM_INPUTS_25": 57.14740075,
    "TALLY_PROOFS_MACHINES_16_BATCH_13_NUM_INPUTS_25": 57.332813625,
    "TALLY_PROOFS_MACHINES_16_BATCH_14_NUM_INPUTS_25": 57.811672958,
    "TALLY_PROOFS_MACHINES_16_BATCH_15_NUM_INPUTS_25": 57.751567334,
    "TALLY_PROOFS_MACHINES_32_BATCH_0_NUM_INPUTS_13": 30.456139583,
    "TALLY_PROOFS_MACHINES_32_BATCH_1_NUM_INPUTS_13": 34.241245625000005,
    "TALLY_PROOFS_MACHINES_32_BATCH_2_NUM_INPUTS_13": 30.253369666999998,
    "TALLY_PROOFS_MACHINES_32_BATCH_3_NUM_INPUTS_13": 30.35968525,
    "TALLY_PROOFS_MACHINES_32_BATCH_4_NUM_INPUTS_13": 30.162670625,
    "TALLY_PROOFS_MACHINES_32_BATCH_5_NUM_INPUTS_13": 30.240472709000002,
    "TALLY_PROOFS_MACHINES_32_BATCH_6_NUM_INPUTS_13": 30.159551792,
    "TALLY_PROOFS_MACHINES_32_BATCH_7_NUM_INPUTS_13": 33.210930792,
    "TALLY_PROOFS_MACHINES_32_BATCH_8_NUM_INPUTS_13": 33.473785833,
    "TALLY_PROOFS_MACHINES_32_BATCH_9_NUM_INPUTS_13": 32.662658708,
    "TALLY_PROOFS_MACHINES_32_BATCH_10_NUM_INPUTS_13": 30.254397333,
    "TALLY_PROOFS_MACHINES_32_BATCH_11_NUM_INPUTS_13": 30.191906416000002,
    "TALLY_PROOFS_MACHINES_32_BATCH_12_NUM_INPUTS_13": 33.342471958000004,
    "TALLY_PROOFS_MACHINES_32_BATCH_13_NUM_INPUTS_13": 30.205689542000002,
    "TALLY_PROOFS_MACHINES_32_BATCH_14_NUM_INPUTS_13": 30.128601167,
    "TALLY_PROOFS_MACHINES_32_BATCH_15_NUM_INPUTS_13": 33.372588,
    "TALLY_PROOFS_MACHINES_32_BATCH_16_NUM_INPUTS_13": 32.806946166,
    "TALLY_PROOFS_MACHINES_32_BATCH_17_NUM_INPUTS_12": 27.917269208,
    "TALLY_PROOFS_MACHINES_32_BATCH_18_NUM_INPUTS_12": 27.962317459,
    "TALLY_PROOFS_MACHINES_32_BATCH_19_NUM_INPUTS_12": 27.791735625,
    "TALLY_PROOFS_MACHINES_32_BATCH_20_NUM_INPUTS_12": 27.859925459,
    "TALLY_PROOFS_MACHINES_32_BATCH_21_NUM_INPUTS_12": 27.943288375,
    "TALLY_PROOFS_MACHINES_32_BATCH_22_NUM_INPUTS_12": 30.332926458000003,
    "TALLY_PROOFS_MACHINES_32_BATCH_23_NUM_INPUTS_12": 27.843957084000003,
    "TALLY_PROOFS_MACHINES_32_BATCH_24_NUM_INPUTS_12": 27.844056000000002,
    "TALLY_PROOFS_MACHINES_32_BATCH_25_NUM_INPUTS_12": 28.019576375,
    "TALLY_PROOFS_MACHINES_32_BATCH_26_NUM_INPUTS_12": 27.921902125,
    "TALLY_PROOFS_MACHINES_32_BATCH_27_NUM_INPUTS_12": 27.948393417,
    "TALLY_PROOFS_MACHINES_32_BATCH_28_NUM_INPUTS_12": 27.930033040999998,
    "TALLY_PROOFS_MACHINES_32_BATCH_29_NUM_INPUTS_12": 27.9155235,
    "TALLY_PROOFS_MACHINES_32_BATCH_30_NUM_INPUTS_12": 27.926252833,
    "TALLY_PROOFS_MACHINES_32_BATCH_31_NUM_INPUTS_12": 27.824415417,
    "TALLY_PROOFS_MACHINES_64_BATCH_0_NUM_INPUTS_7": 16.669524583999998,
    "TALLY_PROOFS_MACHINES_64_BATCH_1_NUM_INPUTS_7": 16.60923,
    "TALLY_PROOFS_MACHINES_64_BATCH_2_NUM_INPUTS_7": 16.740906374999998,
    "TALLY_PROOFS_MACHINES_64_BATCH_3_NUM_INPUTS_7": 16.589472792000002,
    "TALLY_PROOFS_MACHINES_64_BATCH_4_NUM_INPUTS_7": 16.65897,
    "TALLY_PROOFS_MACHINES_64_BATCH_5_NUM_INPUTS_7": 16.590968292000003,
    "TALLY_PROOFS_MACHINES_64_BATCH_6_NUM_INPUTS_7": 16.578973709000003,
    "TALLY_PROOFS_MACHINES_64_BATCH_7_NUM_INPUTS_7": 16.654204834,
    "TALLY_PROOFS_MACHINES_64_BATCH_8_NUM_INPUTS_7": 16.714555583000003,
    "TALLY_PROOFS_MACHINES_64_BATCH_9_NUM_INPUTS_7": 16.437561875,
    "TALLY_PROOFS_MACHINES_64_BATCH_10_NUM_INPUTS_7": 16.639752875,
    "TALLY_PROOFS_MACHINES_64_BATCH_11_NUM_INPUTS_7": 16.594683916999998,
    "TALLY_PROOFS_MACHINES_64_BATCH_12_NUM_INPUTS_7": 16.52942775,
    "TALLY_PROOFS_MACHINES_64_BATCH_13_NUM_INPUTS_7": 16.58794625,
    "TALLY_PROOFS_MACHINES_64_BATCH_14_NUM_INPUTS_7": 16.633491333000002,
    "TALLY_PROOFS_MACHINES_64_BATCH_15_NUM_INPUTS_7": 16.572774125,
    "TALLY_PROOFS_MACHINES_64_BATCH_16_NUM_INPUTS_7": 16.626983250000002,
    "TALLY_PROOFS_MACHINES_64_BATCH_17_NUM_INPUTS_6": 14.295408833,
    "TALLY_PROOFS_MACHINES_64_BATCH_18_NUM_INPUTS_6": 15.976756959000001,
    "TALLY_PROOFS_MACHINES_64_BATCH_19_NUM_INPUTS_6": 15.911873041000002,
    "TALLY_PROOFS_MACHINES_64_BATCH_20_NUM_INPUTS_6": 15.703689749999999,
    "TALLY_PROOFS_MACHINES_64_BATCH_21_NUM_INPUTS_6": 14.320429958999998,
    "TALLY_PROOFS_MACHINES_64_BATCH_22_NUM_INPUTS_6": 15.872518625000001,
    "TALLY_PROOFS_MACHINES_64_BATCH_23_NUM_INPUTS_6": 14.374194750000001,
    "TALLY_PROOFS_MACHINES_64_BATCH_24_NUM_INPUTS_6": 14.318143792,
    "TALLY_PROOFS_MACHINES_64_BATCH_25_NUM_INPUTS_6": 15.741450083,
    "TALLY_PROOFS_MACHINES_64_BATCH_26_NUM_INPUTS_6": 14.317408458,
    "TALLY_PROOFS_MACHINES_64_BATCH_27_NUM_INPUTS_6": 14.22352125,
    "TALLY_PROOFS_MACHINES_64_BATCH_28_NUM_INPUTS_6": 14.343224542,
    "TALLY_PROOFS_MACHINES_64_BATCH_29_NUM_INPUTS_6": 15.445497958,
    "TALLY_PROOFS_MACHINES_64_BATCH_30_NUM_INPUTS_6": 14.304999625,
    "TALLY_PROOFS_MACHINES_64_BATCH_31_NUM_INPUTS_6": 15.700757958,
    "TALLY_PROOFS_MACHINES_64_BATCH_32_NUM_INPUTS_6": 14.327892792,
    "TALLY_PROOFS_MACHINES_64_BATCH_33_NUM_INPUTS_6": 14.327010334,
    "TALLY_PROOFS_MACHINES_64_BATCH_34_NUM_INPUTS_6": 15.529706000000001,
    "TALLY_PROOFS_MACHINES_64_BATCH_35_NUM_INPUTS_6": 14.315085708,
    "TALLY_PROOFS_MACHINES_64_BATCH_36_NUM_INPUTS_6": 15.397257291,
    "TALLY_PROOFS_MACHINES_64_BATCH_37_NUM_INPUTS_6": 15.59544325,
    "TALLY_PROOFS_MACHINES_64_BATCH_38_NUM_INPUTS_6": 14.217231833,
    "TALLY_PROOFS_MACHINES_64_BATCH_39_NUM_INPUTS_6": 15.645586916000001,
    "TALLY_PROOFS_MACHINES_64_BATCH_40_NUM_INPUTS_6": 14.346203041999999,
    "TALLY_PROOFS_MACHINES_64_BATCH_41_NUM_INPUTS_6": 15.626495417,
    "TALLY_PROOFS_MACHINES_64_BATCH_42_NUM_INPUTS_6": 15.465944125,
    "TALLY_PROOFS_MACHINES_64_BATCH_43_NUM_INPUTS_6": 15.6998315,
    "TALLY_PROOFS_MACHINES_64_BATCH_44_NUM_INPUTS_6": 15.645760083999999,
    "TALLY_PROOFS_MACHINES_64_BATCH_45_NUM_INPUTS_6": 14.268563834,
    "TALLY_PROOFS_MACHINES_64_BATCH_46_NUM_INPUTS_6": 15.539647542,
    "TALLY_PROOFS_MACHINES_64_BATCH_47_NUM_INPUTS_6": 14.299167917,
    "TALLY_PROOFS_MACHINES_64_BATCH_48_NUM_INPUTS_6": 15.736143458,
    "TALLY_PROOFS_MACHINES_64_BATCH_49_NUM_INPUTS_6": 14.405555834000001,
    "TALLY_PROOFS_MACHINES_64_BATCH_50_NUM_INPUTS_6": 15.818317834,
    "TALLY_PROOFS_MACHINES_64_BATCH_51_NUM_INPUTS_6": 16.572784333,
    "TALLY_PROOFS_MACHINES_64_BATCH_52_NUM_INPUTS_6": 14.491854292,
    "TALLY_PROOFS_MACHINES_64_BATCH_53_NUM_INPUTS_6": 14.384364458,
    "TALLY_PROOFS_MACHINES_64_BATCH_54_NUM_INPUTS_6": 16.091475792,
    "TALLY_PROOFS_MACHINES_64_BATCH_55_NUM_INPUTS_6": 15.657770167,
    "TALLY_PROOFS_MACHINES_64_BATCH_56_NUM_INPUTS_6": 14.39135375,
    "TALLY_PROOFS_MACHINES_64_BATCH_57_NUM_INPUTS_6": 14.250927667,
    "TALLY_PROOFS_MACHINES_64_BATCH_58_NUM_INPUTS_6": 15.768531875,
    "TALLY_PROOFS_MACHINES_64_BATCH_59_NUM_INPUTS_6": 14.476250958000001,
    "TALLY_PROOFS_MACHINES_64_BATCH_60_NUM_INPUTS_6": 14.312253875,
    "TALLY_PROOFS_MACHINES_64_BATCH_61_NUM_INPUTS_6": 14.446708875,
    "TALLY_PROOFS_MACHINES_64_BATCH_62_NUM_INPUTS_6": 14.243540166999999,
    "TALLY_PROOFS_MACHINES_64_BATCH_63_NUM_INPUTS_6": 14.404396916
}"""

data :dict = json.loads(data_str)

# %%
import json
import re
import matplotlib.pyplot as plt
from collections import defaultdict

# Extract and group timings by number of machines
machine_timings = defaultdict(list)
for key, value in data.items():
    match = re.search(r'MACHINES_(\d+)_', key)
    if match:
        machines = int(match.group(1))
        machine_timings[machines].append(value)

# Compute average total time for each machine count
average_times = {m: sum(times) / len(times) for m, times in machine_timings.items()}
# for m in average_times:
#     average_times[m] += save_time  # add constant save time

# Calculate speedup relative to the single-machine baseline
base_time = average_times[1]
speedups = {m: base_time / t for m, t in average_times.items()}

# Prepare data for plotting
machines_sorted = sorted(speedups)
measured_speedup = [speedups[m] for m in machines_sorted]
ideal_speedup = machines_sorted  # ideal is linear speedup: speedup = num_machines

# Plotting
plt.figure(figsize=(8, 5))
plt.plot(machines_sorted, measured_speedup, marker='o', label='Measured Speedup')
# plt.plot(machines_sorted, ideal_speedup, linestyle='--', color='gray', label='Ideal Speedup')

plt.xlabel('Number of Machines')
plt.ylabel('Speedup')
plt.title('Measured Speedup of Running Distributed Zero-Knowledge Proof Circuits')
plt.grid(True)
plt.xticks(machines_sorted)
plt.tight_layout()
plt.savefig("images/ideal_speedup_plot.svg", format="svg", dpi=300, transparent=True)
plt.show()

# %%
import json
import re
import matplotlib.pyplot as plt
from collections import defaultdict

# Extract and group timings by number of machines
machine_timings = defaultdict(list)
for key, value in data.items():
    match = re.search(r'MACHINES_(\d+)_', key)
    if match:
        machines = int(match.group(1))
        machine_timings[machines].append(value)

# Compute average total time for each machine count
average_times = {m: sum(times) / len(times) for m, times in machine_timings.items()}
for m in average_times:
    average_times[m] += save_time  # add constant save time

# Calculate speedup relative to the single-machine baseline
base_time = average_times[1]
speedups = {m: base_time / t for m, t in average_times.items()}

# Prepare data for plotting
machines_sorted = sorted(speedups)
measured_speedup = [speedups[m] for m in machines_sorted]
ideal_speedup = machines_sorted  # ideal is linear speedup: speedup = num_machines

# Plotting
plt.figure(figsize=(8, 5))
plt.plot(machines_sorted, measured_speedup, marker='o', label='Measured Speedup')
plt.plot(machines_sorted, ideal_speedup, linestyle='--', color='gray', label='Ideal Speedup')

plt.xlabel('Number of Machines')
plt.ylabel('Speedup')
plt.title('Measured Speedup of Preparing and Running Distributed Zero-Knowledge Proof Circuits')
plt.grid(True)
plt.legend()
plt.xticks(machines_sorted)
plt.tight_layout()
plt.savefig("images/real_speedup_plot.svg", format="svg", dpi=300, transparent=True)
plt.show()
