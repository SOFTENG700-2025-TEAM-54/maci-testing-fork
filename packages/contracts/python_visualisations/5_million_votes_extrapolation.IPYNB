# %%
FIELDS =[ 
    "SIGN_UP",
    "UPDATE_POLL",
    "JOIN_POLL",
    "TOTAL_VALID_VOTES",
    "PROCESS_MESSAGES",
    "TALLY_PROOFS"
]

five_million_estimated = {
    "data": {
      "numUsers": 5000000
    },
    "SIGN_UP": 65450.86885508632,
    "UPDATE_POLL": 27665.562729708643,
    "JOIN_POLL": 15003.11970455179,
    "TOTAL_VALID_VOTES": 351117.73954971903,
    "PROCESS_MESSAGES": 449189.0471183139,
    "TALLY_PROOFS": 879173.8187390567
  }
five_million_estimated["TOTAL_VALID_VOTES"] = five_million_estimated["TOTAL_VALID_VOTES"] * 0.23  # scale down for better visibility


print("Seconds for 5 million", sum([five_million_estimated[field] for field in FIELDS ]))
print("Seconds for 5 million without proof generation", sum([five_million_estimated[field] for field in FIELDS if field != "TALLY_PROOFS" ]))
# Out:
# Seconds for 5 million 1517239.497243153
# Seconds for 5 million without proof generation 638065.6785040961
